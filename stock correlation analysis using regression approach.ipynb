# %%
import pandas as pd

# %%
data = pd.read_csv('merge.csv')

# %%
data.tail(5)
# Out:
#            Date       icici         sbi
# 245  20-03-2023  836.450012  519.200012
# 246  21-03-2023  852.400024  521.849976
# 247  22-03-2023  860.200012  521.549988
# 248  23-03-2023  855.450012  512.750000
# 249  24-03-2023  852.400024  505.350006

# %%
# correlation:


# build a regression approach: 

# assume: 

    # icici is independent column (x)
    # sbi is dependent col  (y)
    
X = data.iloc[:,1:2].values

# %%
X
# Out:
# array([[699.25    ],
#        [710.349976],
#        [715.299988],
#        [730.900024],
#        [730.299988],
#        [736.25    ],
#        [746.599976],
#        [741.799988],
#        [741.599976],
#        [748.549988],
#        [754.299988],
#        [759.599976],
#        [763.849976],
#        [762.25    ],
#        [757.799988],
#        [766.299988],
#        [755.549988],
#        [762.349976],
#        [747.650024],
#        [752.200012],
#        [753.75    ],
#        [736.700012],
#        [747.150024],
#        [743.299988],
#        [741.      ],
#        [724.25    ],
#        [728.799988],
#        [719.25    ],
#        [710.349976],
#        [711.299988],
#        [714.200012],
#        [695.799988],
#        [677.349976],
#        [683.      ],
#        [710.      ],
#        [707.349976],
#        [690.299988],
#        [709.549988],
#        [711.049988],
#        [708.150024],
#        [713.349976],
#        [728.5     ],
#        [739.799988],
# ...

# %%
Y = data.iloc[:,1].values

# %%
Y
# Out:
# array([699.25    , 710.349976, 715.299988, 730.900024, 730.299988,
#        736.25    , 746.599976, 741.799988, 741.599976, 748.549988,
#        754.299988, 759.599976, 763.849976, 762.25    , 757.799988,
#        766.299988, 755.549988, 762.349976, 747.650024, 752.200012,
#        753.75    , 736.700012, 747.150024, 743.299988, 741.      ,
#        724.25    , 728.799988, 719.25    , 710.349976, 711.299988,
#        714.200012, 695.799988, 677.349976, 683.      , 710.      ,
#        707.349976, 690.299988, 709.549988, 711.049988, 708.150024,
#        713.349976, 728.5     , 739.799988, 748.5     , 752.849976,
#        752.650024, 749.75    , 744.299988, 746.75    , 735.25    ,
#        729.5     , 732.75    , 720.      , 688.      , 685.5     ,
#        687.25    , 678.5     , 686.849976, 685.950012, 696.099976,
#        686.599976, 699.150024, 713.450012, 717.349976, 710.299988,
#        702.75    , 707.200012, 703.900024, 720.099976, 719.450012,
# ...

# %%
# BUILD OUR SIMPLE LINEAR REGRESSION

# %%
# Simple Linear Regression
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X,Y)
# Out:
# LinearRegression()

# %%
# based on our understanding: 

y = b0 + b1*x

# %%
model.coef_[0]
# Out:
# 1.0

# %%
model.intercept_
# Out:
# 0.0

# %%
# icici is dependent column (y1)
    # sbi is independent col  (x1)

# %%
y1 = data.iloc[:,1].values

# %%
y1
# Out:
# array([699.25    , 710.349976, 715.299988, 730.900024, 730.299988,
#        736.25    , 746.599976, 741.799988, 741.599976, 748.549988,
#        754.299988, 759.599976, 763.849976, 762.25    , 757.799988,
#        766.299988, 755.549988, 762.349976, 747.650024, 752.200012,
#        753.75    , 736.700012, 747.150024, 743.299988, 741.      ,
#        724.25    , 728.799988, 719.25    , 710.349976, 711.299988,
#        714.200012, 695.799988, 677.349976, 683.      , 710.      ,
#        707.349976, 690.299988, 709.549988, 711.049988, 708.150024,
#        713.349976, 728.5     , 739.799988, 748.5     , 752.849976,
#        752.650024, 749.75    , 744.299988, 746.75    , 735.25    ,
#        729.5     , 732.75    , 720.      , 688.      , 685.5     ,
#        687.25    , 678.5     , 686.849976, 685.950012, 696.099976,
#        686.599976, 699.150024, 713.450012, 717.349976, 710.299988,
#        702.75    , 707.200012, 703.900024, 720.099976, 719.450012,
# ...

# %%
y1 = data.iloc[:,1].values
x1 = data.iloc[:,2:3].values

# %%
x1
# Out:
# array([[490.700012],
#        [497.5     ],
#        [495.      ],
#        [494.299988],
#        [493.549988],
#        [508.200012],
#        [512.400024],
#        [509.399994],
#        [513.950012],
#        [514.950012],
#        [516.099976],
#        [514.900024],
#        [512.849976],
#        [517.700012],
#        [509.5     ],
#        [511.799988],
#        [509.299988],
#        [516.299988],
#        [500.600006],
#        [494.75    ],
#        [505.5     ],
#        [497.25    ],
#        [507.5     ],
#        [496.299988],
#        [491.      ],
#        [479.649994],
#        [480.      ],
#        [483.950012],
#        [475.899994],
#        [475.200012],
#        [476.549988],
#        [462.649994],
#        [444.649994],
#        [455.      ],
#        [467.299988],
#        [458.      ],
#        [447.5     ],
#        [462.399994],
#        [460.899994],
#        [462.049988],
#        [454.100006],
#        [468.899994],
#        [468.950012],
# ...

# %%
y1 = data.iloc[:,1].values
x1 = data.iloc[:,2:3].values
model1 = LinearRegression()
model1.fit(x1,y1)

# %%
model1.fit(x1,y1)
# Out:
# LinearRegression()

# %%
model1.coef_
# Out:
# array([1.40025795])

# %%
model1.intercept_
# Out:
# 81.19694809190923

# %%
# x1 will be required to predict y1: 

# icici stock price y1:

b0 === intercept
b1 = coef/slope value

# %%
data.head(5)
# Out:
#          Date       icici         sbi
# 0  25-03-2022  699.250000  490.700012
# 1  28-03-2022  710.349976  497.500000
# 2  29-03-2022  715.299988  495.000000
# 3  30-03-2022  730.900024  494.299988
# 4  31-03-2022  730.299988  493.549988

# %%
data.tail(5)
# Out:
#            Date       icici         sbi
# 245  20-03-2023  836.450012  519.200012
# 246  21-03-2023  852.400024  521.849976
# 247  22-03-2023  860.200012  521.549988
# 248  23-03-2023  855.450012  512.750000
# 249  24-03-2023  852.400024  505.350006

# %%
# 505.350006 == x1 === sbi 
# i want to find what will be the value for icici: if sbi is 505.350006

# b0 + b1*x1 = icici value
81.19694809190923 + 1.40025795*505.350006
# Out:
# 788.8173115259569

# %%
# simple linear regression\

# more than one explainatory variable to explain change in y

# %%
# multiple linear regression
